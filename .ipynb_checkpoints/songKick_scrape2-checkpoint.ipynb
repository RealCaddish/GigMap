# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the Songkick page for Lexington events this month
url = 'https://www.songkick.com/metro-areas/24580-us-lexington/july-2024'

# Fetch the webpage content
response = requests.get(url)
content = response.content

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(content, 'html.parser')

# Initialize lists to store the extracted data
artists = []
locations = []
dateTimes = []
artist_links = []

# Extract event details
for event in soup.find_all('li', class_='event-listings-element'):
    print(event)
    
    # Extract artist name
    artist_tag = event.find('p', class_='artists')
    artist_name = artist_tag.strong.get_text(strip=True) if artist_tag else None
    
    #extract artist link
    artist_link_tag = artist_tag.find('a') if artist_tag else None
    artist_link = f"https://www.songkick.com{artist_link_tag['href']}" if artist_link_tag else None

    # Extract event location
    locate_tag = event.find('p', class_='location')
    locate_name = locate_tag.get_text(strip=True) if locate_tag else None
    
    # Extract date and time
    time_element = event.find('time')
    if time_element:
        datetime_value = time_element['datetime']
        time_text = time_element.get_text(strip=True)
    else:
        datetime_value = 'N/A'
        time_text = 'N/A'
    
    # Append extracted data to lists
    artists.append(artist_name)
    locations.append(locate_name)
    dateTimes.append(datetime_value)
    artist_links.append(artist_link)

# Create a DataFrame from the extracted data
data = {
    'Artist': artists,
    'Location': locations,
    'Datetime': dateTimes,
    'Artist Link': artist_links
}

df = pd.DataFrame(data)

# Append the new data to the existing CSV file
csv_filename = 'lexington_events2.csv'

try:
    existing_df = pd.read_csv(csv_filename)
    updated_df = pd.concat([existing_df, df], ignore_index=True)
except FileNotFoundError:
    updated_df = df

# Save the updated DataFrame to the CSV file
updated_df.to_csv(csv_filename, index=False)

print(f'Data saved to {csv_filename}')
# Out:
# <li class="event-listings-element" title="Thursday 04 July 2024">
# <time datetime="2024-07-04"></time>
# <div class="event-details-wrapper">
# <div class="image-wrapper">
# <a class="thumb" href="/concerts/41948676-steel-woods-at-burl">
# <img alt="The Steel Woods Concert Tickets - 2024 Tour Dates" class="artist-profile-image artist lazyload" data-src="//images.sk-static.com/images/media/profile_images/artists/8906034/large_avatar" height="48" src="//assets.sk-static.com/images/default_images/large_avatar/default-artist.png" width="48"/>
# </a>
# </div>
# <div class="artists-venue-location-wrapper">
# <p class="artists">
# <a class="event-link" href="/concerts/41948676-steel-woods-at-burl">
# <span>
# <strong>The Steel Woods</strong>
# </span>
# </a>
# </p>
# <p class="location">
# <span><a class="venue-link" href="/venues/3331354-burl">The Burl</a></span>,
#               <span>
# <span class="city-name">Lexington, KY, US </span>
# </span>
# </p>
# </div>
# <a class="event-link chevron-wrapper" href="/concerts/41948676-steel-woods-at-burl">
# <i class="chevron"></i>
# </a>
# </div>
# <div class="microformat">
# <script type="application/ld+json">[{"@context":"http://schema.org","@type":"Event","name":"The Steel Woods","url":"https://www.songkick.com/concerts/41948676-steel-woods-at-burl?utm_medium=organic\u0026utm_source=microformat","image":"media/profile_images/artists/8906034/huge_avatar","location":{"@type":"Place","address":{"@type":"PostalAddress","addressLocality":"Lexington","addressCountry":"US","addressRegion":"KY","streetAddress":"375 Thompson Rd","postalCode":"40508"},"name":"The Burl","sameAs":null,"geo":{"@type":"GeoCoordinates","latitude":38.05727,"longitude":-84.5193}},"eventStatus":"https://schema.org/EventScheduled","startDate":"2024-07-04","endDate":"2024-07-04","performer":[{"@type":"MusicGroup","name":"The Steel Woods","sameAs":"https://www.songkick.com/artists/8906034-steel-woods?utm_medium=organic\u0026utm_source=microformat"}],"description":"The Steel Woods at The Burl at 2024-07-04","offers":[{"@type":"Offer","url":"http://www.songkick.com/concerts/41948676-steel-woods-at-burl?utm_medium=organic\u0026utm_source=microformat"}]}]</script>
# </div>
# </li>
# <li class="event-listings-element" title="Thursday 04 July 2024">
# <time datetime="2024-07-04T16:00:00-0500"></time>
# <div class="event-details-wrapper">
# <div class="image-wrapper">
# <a class="thumb" href="/concerts/42013289-tyler-deaver-at-lake-reba-recreational-complex-park">
# <img alt="Tyler Deaver Concert Tickets - 2024 Tour Dates" class="artist-profile-image artist lazyload" data-src="//images.sk-static.com/images/media/profile_images/artists/10196820/large_avatar" height="48" src="//assets.sk-static.com/images/default_images/large_avatar/default-artist.png" width="48"/>
# </a>
# </div>
# <div class="artists-venue-location-wrapper">
# <p class="artists">
# <a class="event-link" href="/concerts/42013289-tyler-deaver-at-lake-reba-recreational-complex-park">
# <span>
# <strong>Tyler Deaver</strong>
# </span>
# </a>
# </p>
# <p class="location">
# <span><a class="venue-link" href="/venues/4570764-lake-reba-recreational-complex-park">Lake Reba Recreational Complex Park</a></span>,
#               <span>
# <span class="city-name">Richmond, KY, US </span>
# </span>
# </p>
# </div>
# <a class="event-link chevron-wrapper" href="/concerts/42013289-tyler-deaver-at-lake-reba-recreational-complex-park">
# <i class="chevron"></i>
# </a>
# </div>
# <div class="microformat">
# <script type="application/ld+json">[{"@context":"http://schema.org","@type":"Event","name":"Tyler Deaver","url":"https://www.songkick.com/concerts/42013289-tyler-deaver-at-lake-reba-recreational-complex-park?utm_medium=organic\u0026utm_source=microformat","image":"media/profile_images/artists/10196820/huge_avatar","location":{"@type":"Place","address":{"@type":"PostalAddress","addressLocality":"Richmond","addressCountry":"US","addressRegion":"KY","streetAddress":null,"postalCode":null},"name":"Lake Reba Recreational Complex Park","sameAs":null},"eventStatus":"https://schema.org/EventScheduled","startDate":"2024-07
></time>
# <div class="event-details-wrapper">
# <div class="image-wrapper">
# <a class="thumb" href="/concerts/41799077-stews-us-at-burl">
# <img alt="The Stews (US) Concert Tickets - 2024 Tour Dates" class="artist-profile-image artist lazyload" data-src="//images.sk-static.com/images/media/profile_images/artists/10159438/large_avatar" height="48" src="//assets.sk-static.com/images/default_images/large_avatar/default-artist.png" width="48"/>
# </a>
# </div>
# <div class="artists-venue-location-wrapper">
# <p class="artists">
# <a class="event-link" href="/concerts/41799077-stews-us-at-burl">
# <span>
# <strong>The Stews (US)</strong>
# </span>
# </a>
# </p>
# <p class="location">
# <span><a class="venue-link" href="/venues/3331354-burl">The Burl</a></span>,
#               <span>
# <span class="city-name">Lexington, KY, US </span>
# </span>
# </p>
# </div>
# <a class="event-link chevron-wrapper" href="/concerts/41799077-stews-us-at-burl">
# <i class="chevron"></i>
# </a>
# </div>
# <div class="microformat">
# <script type="application/ld+json">[{"@context":"http://schema.org","@type":"Event","name":"The Stews (US)","url":"https://www.songkick.com/concerts/41799077-stews-us-at-burl?utm_medium=organic\u0026utm_source=microformat","image":"media/profile_images/artists/10159438/huge_avatar","location":{"@type":"Place","address":{"@type":"PostalAddress","addressLocality":"Lexington","addressCountry":"US","addressRegion":"KY","streetAddress":"375 Thompson Rd","postalCode":"40508"},"name":"The Burl","sameAs":null,"geo":{"@type":"GeoCoordinates","latitude":38.05727,"longitude":-84.5193}},"eventStatus":"https://schema.org/EventScheduled","startDate":"2024-07-25","endDate":"2024-07-25","performer":[{"@type":"MusicGroup","name":"The Stews (US)","sameAs":"https://www.songkick.com/artists/10159438-stews-us?utm_medium=organic\u0026utm_source=microformat"}],"description":"The Stews (US) at The Burl at 2024-07-25","offers":[{"@type":"Offer","url":"http://www.songkick.com/concerts/41799077-stews-us-at-burl?utm_medium=organic\u0026utm_source=microformat"}]}]</script>
# </div>
# </li>
# <li class="event-listings-element" title="Friday 26 July 2024">
# <time datetime="2024-07-26T19:00:00-0500"></time>
# <div class="event-details-wrapper">
# <div class="image-wrapper">
# <a class="thumb" href="/concerts/41821447-wilderado-at-burl">
# <img alt="Wilderado Concert Tickets - 2024 Tour Dates" class="artist-profile-image artist lazyload" data-src="//images.sk-static.com/images/media/profile_images/artists/8812754/large_avatar" height="48" src="//assets.sk-static.com/images/default_images/large_avatar/default-artist.png" width="48"/>
# </a>
# </div>
# <div class="artists-venue-location-wrapper">
# <p class="artists">
# <a class="event-link" href="/concerts/41821447-wilderado-at-burl">
# <span>
# <strong>Wilderado</strong>
# <span class="support">HARBOUR and Windser</span>
# </span>
# </a>
# </p>
# <p class="location">
# <span><a class="venue-link" href="/venues/3331354-burl">The Burl</a></span>,
#               <span>
# <span class="city-name">Lexington, KY, US </span>
# </span>
# </p>
# </div>
# <a class="event-link chevron-wrapper" href="/concerts/41821447-wilderado-at-burl">
# <i class="chevron"></i>
# </a>
# </div>
# <div class="microformat">
# <script type="application/ld+json">[{"@context":"http://schema.org","@type":"Event","name":"Wilderado","url":"https://www.songkick.com/concerts/41821447-wilderado-at-burl?utm_medium=organic\u0026utm_source=microformat","image":"media/profile_images/artists/8812754/huge_avatar","location":{"@type":"Place","address":{"@type":"PostalAddress","addressLocality":"Lexington","addressCountry":"US","addressRegion":"KY","streetAddress":"375 Thompson Rd","postalCode":"40508"},"name":"The Burl","sameAs":null,"geo":{"@type":"GeoCoordinates","latitude":38.05727,"longitude":-84.5193}},"eventStatus":"https://schema.org/EventScheduled","startDate":"2024-07-26T19:00:00-0500","endDate":"2024-07-26","performer":[{"@type":"MusicGroup","name":"Wilderado","sameAs":"https://www.songkick.com/artists/8812754-wilderado?utm_medium=organic\u0026utm_source=microformat"},{"@type":"MusicGroup","name":"HARBOUR","sameAs":"https://www.songkick.com/artists/10249475-harbour?utm_medium=organic\u0026utm_source=microformat"},{"@type":"MusicGroup","name":"Windser","sameAs":"https://www.songkick.com/artists/10170392-windser?utm_medium=organic\u0026utm_source=microformat"}],"description":"Wilderado at The Burl at 2024-07-26T19:00:00-0500","offers":[{"@type":"Offer","url":"http://www.songkick.com/concerts/41821447-wilderado-at-burl?utm_medium=organic\u0026utm_source=microformat"}]}]</script>
# </div>
# </li>
# <li class="event-listings-element" title="Friday 26 July 2024">
# <time datetime="2024-07-26T20:00:00-0500"></time>
# <div class="event-details-wrapper">
# <div class="image-wrapper">
# <a class="thumb" href="/concerts/42030070-home-grown-head-at-als">
# <img alt="Home Grown Head Concert Tickets - 2024 Tour Dates" class="artist-profile-image artist lazyload" data-src="//images.sk-static.com/images/media/profile_images/artists/10108021/large_avatar" height="48" src="//assets.sk-static.com/images/default_images/large_avatar/default-artist.png" width="48"/>
# </a>
# </div>
# <div class="artists-venue-location-wrapper">
# <p class="artists">
# <a class="event-link" href="/concerts/42030070-home-grown-head-at-als">
# <span>
# <strong>Home Grown Head</strong>
# <span class="support">Jameron</span>
# </span>
# </a>
# </p>
# <p class="location">
# <span><a class="venue-link" href="/venues/2042014-als">Al's</a></span>,
#               <span>
# <span class="city-name">Lexington, KY, US </span>
# </span>
# </p>
# </div>
# <a class="event-link chevron-wrapper" href="/concerts/42030070-home-grown-head-at-als">
# <i class="chevron"></i>
# </a>
# </div>
# <div class="microformat">
# <script type="application/ld+json">[{"@context":"http://schema.org","@type":"Event","name":"Home Grown Head","url":"https://www.songkick.com/concerts/42030070-home-grown-head-at-als?utm_medium=organic\u0026utm_source=microformat","image":"media/profile_images/artists/10108021/huge_avatar","location":{"@type":"Place","address":{"@type":"PostalAddress","addressLocality":"Lexington","addressCountry":"US","addressRegion":"KY","streetAddress":"607 N. LImestone St.","postalCode":null},"name":"Al's","sameAs":null,"geo":{"@type":"GeoCoordinates","latitude":38.05428,"longitude":-84.48633}},"eventStatus":"https://schema.org/EventScheduled","startDate":"2024-07-26T20:00:00-0500","endDate":"2024-07-26","performer":[{"@type":"MusicGroup","name":"Home Grown Head","sameAs":"https://www.songkick.com/artists/10108021-home-grown-head?utm_medium=organic\u0026utm_source=microformat"},{"@type":"MusicGroup","name":"Jameron","sameAs":"https://www.songkick.com/artists/10194454-jameron?utm_medium=organic\u0026utm_source=microformat"}],"description":"Home Grown Head at Al's at 2024-07-26T20:00:00-0500","offers":[{"@type":"Offer","url":"http://www.songkick.com/concerts/42030070-home-grown-head-at-als?utm_medium=organic\u0026utm_source=microformat"}]}]</script>
# </div>
# </li>
# <li class="event-listings-element" title="Saturday 27 July 2024">
# <time datetime="2024-07-27"></time>
# <div class="event-details-wrapper">
# <div class="image-wrapper">
# <a class="thumb" href="/concerts/41698871-fruit-bats-at-burl">
# <img alt="Fruit Bats Concert Tickets - 2024 Tour Dates" class="artist-profile-image artist lazyload" data-src="//images.sk-static.com/images/media/profile_images/artists/500479/large_avatar" height="48" src="//assets.sk-static.com/images/default_images/large_avatar/default-artist.png" width="48"/>
# </a>
# </div>
# <div class="artists-venue-location-wrapper">
# <p class="artists">
# <a class="event-link" href="/concerts/41698871-fruit-bats-at-burl">
# <span>
# <strong>Fruit Bats</strong>
# <span class="support">Carriers</span>
# </span>
# </a>
# </p>
# <p class="location">
# <span><a class="venue-link" href="/venues/3331354-burl">The Burl</a></span>,
#               <span>
# <span class="city-name">Lexington, KY, US </span>
# </span>
# </p>
# </div>
# <a class="event-link chevron-wrapper" href="/concerts/41698871-fruit-bats-at-burl">
# <i class="chevron"></i>
# </a>
# </div>
# <div class="microformat">
# <script type="application/ld+json">[{"@context":"http://schema.org","@type":"Event","name":"Fruit Bats","url":"https://www.songkick.com/concerts/41698871-fruit-bats-at-burl?utm_medium=organic\u0026utm_source=microformat","image":"media/profile_images/artists/500479/huge_avatar","location":{"@type":"Place","address":{"@type":"PostalAddress","addressLocality":"Lexington","addressCountry":"US","addressRegion":"KY","streetAddress":"375 Thompson Rd","postalCode":"40508"},"name":"The Burl","sameAs":null,"geo":{"@type":"GeoCoordinates","latitude":38.05727,"longitude":-84.5193}},"eventStatus":"https://schema.org/EventScheduled","startDate":"2024-07-27","endDate":"2024-07-27","performer":[{"@type":"MusicGroup","name":"Fruit Bats","sameAs":"https://www.songkick.com/artists/500479-fruit-bats?utm_medium=organic\u0026utm_source=microformat"},{"@type":"MusicGroup","name":"Carriers","sameAs":"https://www.songkick.com/artists/2002712-carriers?utm_medium=organic\u0026utm_source=microformat"}],"description":"Fruit Bats at The Burl at 2024-07-27","offers":[{"@type":"Offer","url":"http://www.songkick.com/concerts/
utm_medium=organic\u0026utm_source=microformat"}]}]</script>
# </div>
# </li>
# <li class="event-listings-element" title="Wednesday 31 July 2024">
# <time datetime="2024-07-31T19:00:00-0500"></time>
# <div class="event-details-wrapper">
# <div class="image-wrapper">
# <a class="thumb" href="/concerts/42005174-breed-official-at-als-bar">
# <img alt="Breed (Official) Concert Tickets - 2024 Tour Dates" class="artist-profile-image artist lazyload" data-src="//images.sk-static.com/images/media/profile_images/artists/10236976/large_avatar" height="48" src="//assets.sk-static.com/images/default_images/large_avatar/default-artist.png" width="48"/>
# </a>
# </div>
# <div class="artists-venue-location-wrapper">
# <p class="artists">
# <a class="event-link" href="/concerts/42005174-breed-official-at-als-bar">
# <span>
# <strong>Breed (Official)</strong>
# </span>
# </a>
# </p>
# <p class="location">
# <span><a class="venue-link" href="/venues/92275-als-bar">Al's Bar</a></span>,
#               <span>
# <span class="city-name">Lexington, KY, US </span>
# </span>
# </p>
# </div>
# <a class="event-link chevron-wrapper" href="/concerts/42005174-breed-official-at-als-bar">
# <i class="chevron"></i>
# </a>
# </div>
# <div class="microformat">
# <script type="application/ld+json">[{"@context":"http://schema.org","@type":"Event","name":"Breed (Official)","url":"https://www.songkick.com/concerts/42005174-breed-official-at-als-bar?utm_medium=organic\u0026utm_source=microformat","image":"media/profile_images/artists/10236976/huge_avatar","location":{"@type":"Place","address":{"@type":"PostalAddress","addressLocality":"Lexington","addressCountry":"US","addressRegion":"KY","streetAddress":"601 N Limestone","postalCode":"40508"},"name":"Al's Bar","sameAs":null,"geo":{"@type":"GeoCoordinates","latitude":38.05413,"longitude":-84.48638}},"eventStatus":"https://schema.org/EventScheduled","startDate":"2024-07-31T19:00:00-0500","endDate":"2024-07-31","performer":[{"@type":"MusicGroup","name":"Breed (Official)","sameAs":"https://www.songkick.com/artists/10236976-breed-official?utm_medium=organic\u0026utm_source=microformat"}],"description":"Breed (Official) at Al's Bar at 2024-07-31T19:00:00-0500","offers":[{"@type":"Offer","url":"http://www.songkick.com/concerts/42005174-breed-official-at-als-bar?utm_medium=organic\u0026utm_source=microformat"}]}]</script>
# </div>
# </li>
# Data saved to lexington_events2.csv

# %% [markdown]
# ## Take the output csv and split the Datetime field to Date and Time. Convert the time from Military Time to Imperial

# %%
# Load the CSV file
file_path = 'lexington_events2.csv'
data = pd.read_csv(file_path)

# Function to separate datetime into date and time
def split_datetime(row):
    if 'T' in row['Datetime']:
        date_time = row['Datetime'].split('T')[0]
        time = row['Datetime'].split('T')[1][:5]  # assuming the time format is HH:MM:SS
    else:
        date_time = row['Datetime']
        time = None  # No time provided
    return pd.Series([date_time, time])

# Function to convert time from military to imperial
def convert_to_imperial(time_str):
    if time_str is not None:
        time_obj = pd.to_datetime(time_str, format='%H:%M')
        return time_obj.strftime('%I:%M %p')
    return None

# Apply the function to split Datetime into Date and Time columns
data[['Date', 'Time']] = data.apply(split_datetime, axis=1)

# Convert Time to imperial format
data['Time'] = data['Time'].apply(convert_to_imperial)

# Saving the modified DataFrame to a new CSV file
output_file_path = 'lexington_events_time_imperial.csv'  # Change this to your desired file path
data.to_csv(output_file_path, index=False)

print(f"File saved successfully at {output_file_path}")
# Out:
# File saved successfully at lexington_events_time_imperial.csv
